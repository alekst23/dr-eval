# %% [markdown]
# # Experiment Notebook - Test Evaluation
# This notebook will illustrate how to evaluate the results of a Test Run

# %% [markdown]
# # Customization

# %%
test_name = "wiqiqa_ragtag_gpt35turbo"

# %% [markdown]
# # Setup

# %%
import sqlite3
# Create a connection to the database
db_connection = sqlite3.connect('../experiment.db')

# set warning level logging
from logging import basicConfig, WARNING, getLogger
basicConfig(level=WARNING)
logger = getLogger(__name__)

# Set httpx logging level to WARNING
httpx_logger = getLogger('httpx')
httpx_logger.setLevel(WARNING)

import sys
import os

# Assuming the notebook is in the same directory as the 'custom' package
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# ## A - Load test run info

# %%
# Load the test run
from eval_data.models.testrun import TestRunModel, TestRunType

test_run = TestRunModel(db_connection).get_test_run_by_name(description=test_name)
print(f"Test Run found with ID: {test_run.id}")
# Out:
# Test Run found with ID: 4

# %% [markdown]
# ## B - Setting up Evaluation Functions
# In order to evaluate a test, we need to create library of functions that will evaluate the responses. We can then assign these Evaluation Functions to different test runs.
#
# The following will create a map of Evaluation Functions

# %%
from eval_data.models.evalfunction import EvalFunctionModel, EvalFunctionType
from custom.eval_functions import eval_ragas_precision, eval_ragas_recall, eval_ragas_answer_relevancy, eval_ragas_faithfulness

# Create Test Evals
eval_function_model = EvalFunctionModel(db_connection)
eval_function_list = [
    eval_function_model.add_or_get_eval_function(
        EvalFunctionType(
            name="ragas-precision", 
            description="Ragas - Context precision", 
            eval_function=eval_ragas_precision)
    ),
    eval_function_model.add_or_get_eval_function(
        EvalFunctionType(
            name="ragas-recall", 
            description="Ragas - Context recall",
            eval_function=eval_ragas_recall)
    ),
    eval_function_model.add_or_get_eval_function(
        EvalFunctionType(
            name="ragas-answer-relevancy", 
            description="Ragas - Answer Relevancy",
            eval_function=eval_ragas_answer_relevancy)
    ),
    eval_function_model.add_or_get_eval_function(
        EvalFunctionType(
            name="ragas-faithfulness", 
            description="Ragas - Faithfulness",
            eval_function=eval_ragas_faithfulness)
    )
]

print(f"Eval Function: {[e.id for e in eval_function_list]}")
# Out:
# Eval Function: [1, 2, 3, 4]

# %% [markdown]
# ## C - Assign Evaluation Functions to a Test Run

# %%
# Create a Test Eval Config to assign Test Evals to the Test Run
from packages.data.src.eval_data.models.testevalconfig import TestEvalConfigModel, TestEvalConfigType
from typing import List

test_eval_config_model = TestEvalConfigModel(db_connection)
test_eval_list: List[TestEvalConfigType] = test_eval_config_model.get_test_eval_configs_by_test_run_id(test_run.id)

# Resume an existing eval run
for eval_function in eval_function_list:
    if eval_function.id not in [test_eval.eval_function_id for test_eval in test_eval_list]:
        test_eval_config = TestEvalConfigType(test_run_id=test_run.id, eval_function_id=eval_function.id)
        test_eval_config.id = test_eval_config_model.add_test_eval_config(test_eval_config)
        test_eval_list.append(test_eval_config)
        print(f"Added Test Eval Config: {test_eval_config.id}")
    else:
        print(f"Eval Function already assigned to Test Run: {eval_function.id}")
# Out:
# Eval Function already assigned to Test Run: 1
# Eval Function already assigned to Test Run: 2
# Eval Function already assigned to Test Run: 3
# Eval Function already assigned to Test Run: 4

# %% [markdown]
# ## D - Run the evaluation Functions on all Responses and Contexts

# %%
import nest_asyncio
from tqdm import tqdm  # Import tqdm for progress bar

nest_asyncio.apply()

# Get all responses
from eval_data.models.response import ResponseModel
from eval_data.models.question import QuestionModel
from eval_data.models.context import ContextModel
from eval_data.models.responseeval import ResponseEvalModel, ResponseEvalType

from pandas import DataFrame

question_model = QuestionModel(db_connection)
context_model = ContextModel(db_connection)
response_model = ResponseModel(db_connection)
response_eval_model = ResponseEvalModel(db_connection)

responses = response_model.get_responses_by_test_run_id(test_run.id)
response_evals = response_eval_model.get_response_evals_by_test_run_id(test_run.id)

# filter out responses that have already been evaluated
response_ids = [r.response_id for r in response_evals]
responses_trimed = [r for r in responses if r.id not in response_ids]
count_skipped = len(responses) - len(responses_trimed)

# Add a progress bar
for i, r in enumerate(tqdm(responses_trimed, desc="Processing Responses")):
    question = question_model.get_question_by_id(r.question_id)
    context = context_model.get_contexts_by_response_id(response_id=r.id)
    evals = response_eval_model.get_response_evals_by_response_id(response_id=r.id)

    # Skip evals that were done
    test_eval_ids = [e.test_eval_config_id for e in evals]
    test_eval_list_trimed = [e for e in test_eval_list if e.id not in test_eval_ids]
    for test_eval in test_eval_list_trimed:
        func = eval_function_model.get_eval_function_by_id(test_eval.eval_function_id).eval_function
        eval_result: float = func(
            questions=[question.question],
            answers=[r.response],
            ground_truths=[question.answer],
            contexts=[[c.text for c in context]]
        )
        response_eval_model.add_response_eval(
            ResponseEvalType(
                test_run_id=test_run.id,
                question_id=question.id,
                response_id=r.id,
                test_eval_config_id=test_eval.id,
                eval_score=eval_result if eval_result is not None else 0
            )
        )
# Out:
# Processing Responses:   0%|          | 0/201 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# >>> eval_rags > result = {'context_precision': 0.0000}
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# >>> eval_rags > result = {'context_recall': 0.0000}
# Processing Responses:   0%|          | 0/201 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 38
#      36 for test_eval in test_eval_list_trimed:
#      37     func = eval_function_model.get_eval_function_by_id(test_eval.eval_function_id).eval_function
# ---> 38     eval_result: float = func(
#      39         questions=[question.question],
#      40         answers=[r.response],
#      41         ground_truths=[question.answer],
#      42         contexts=[[c.text for c in context]]
#      43     )
#      44     response_eval_model.add_response_eval(
#      45         ResponseEvalType(
#      46             test_run_id=test_run.id,
#    (...)
#      51         )
#      52     )
#
# File ~/Documents/projects/dr-eval/custom/eval_functions.py:42, in eval_ragas_answer_relevancy(questions, contexts, answers, ground_truths)
#      41 def eval_ragas_answer_relevancy(questions: list[str], contexts: list[list[str]], answers: list[str], ground_truths: list[list[str]])->float:
# ---> 42     return eval_ragas(answer_relevancy, questions, contexts, answers, ground_truths)
#
# File ~/Documents/projects/dr-eval/custom/eval_functions.py:18, in eval_ragas(test_function, questions, contexts, answers, ground_truths)
#      11 def eval_ragas(test_function, questions: list[str], contexts: list[list[str]], answers: list[str], ground_truths: list[list[str]]):
#      12     dataset = Dataset.from_dict({
#      13         'question': questions,
#      14         'contexts': contexts,
#      15         'answer': answers,
#      16         'ground_truth': ground_truths
#      17     })
# ---> 18     result = evaluate(
#      19         dataset,
#      20         metrics=[
#      21             test_function
#      22         ],
#      23     )
#      25     print(f">>> eval_rags > result = {result}")
#      26     res = next(iter(result.values()))
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ragas/_analytics.py:129, in track_was_completed.<locals>.wrapper(*args, **kwargs)
#     126 @wraps(func)
#     127 def wrapper(*args: P.args, **kwargs: P.kwargs) -> t.Any:
#     128     track(IsCompleteEvent(event_type=func.__name__, is_completed=False))
# --> 129     result = func(*args, **kwargs)
#     130     track(IsCompleteEvent(event_type=func.__name__, is_completed=True))
#     132     return result
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ragas/evaluation.py:295, in evaluate(dataset, metrics, llm, embeddings, callbacks, in_ci, run_config, token_usage_parser, raise_exceptions, column_map, show_progress)
#     292 scores = []
#     293 try:
#     294     # get the results
# --> 295     results = executor.results()
#     296     if results == []:
#     297         raise ExceptionInRunner()
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ragas/executor.py:118, in Executor.results(self)
#     114         results.append(r)
#     116     return results
# --> 118 results = asyncio.run(_aresults())
#     119 sorted_results = sorted(results, key=lambda x: x[0])
#     120 return [r[1] for r in sorted_results]
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py:88, in Handle._run(self)
#      86 def _run(self):
#      87     try:
# ---> 88         self._context.run(self._callback, *self._args)
#      89     except (SystemExit, KeyboardInterrupt):
#      90         raise
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:303, in Task.__step(self, exc)
#     301 _enter_task(self._loop, self)
#     302 try:
# --> 303     self.__step_run_and_handle_result(exc)
#     304 finally:
#     305     _leave_task(self._loop, self)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ragas/executor.py:105, in Executor.results.<locals>._aresults()
#     103 async def _aresults() -> t.List[t.Any]:
#     104     results = []
# --> 105     for future in tqdm(
#     106         futures_as_they_finish,
#     107         desc=self.desc,
#     108         total=len(self.jobs),
#     109         # whether you want to keep the progress bar after completion
#     110         leave=self.keep_progress_bar,
#     111         disable=not self.show_progress,
#     112     ):
#     113         r = await future
#     114         results.append(r)
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/tqdm/notebook.py:238, in tqdm_notebook.__init__(self, *args, **kwargs)
#     236 self.displayed = False
#     237 if display_here and self.delay <= 0:
# --> 238     display(self.container)
#     239     self.displayed = True
#     240 self.disp = self.display
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/IPython/core/display_functions.py:305, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     302         if metadata:
#     303             # kwarg-specified metadata gets precedence
#     304             _merge(md_dict, metadata)
# --> 305         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     306 if display_id:
#     307     return DisplayHandle(display_id)
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/IPython/core/display_functions.py:93, in publish_display_data(data, metadata, source, transient, **kwargs)
#      90 if transient:
#      91     kwargs['transient'] = transient
# ---> 93 display_pub.publish(
#      94     data=data,
#      95     metadata=metadata,
#      96     **kwargs
#      97 )
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)
#      86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)
#     101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~/Documents/projects/dr-eval/venv/lib/python3.12/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
